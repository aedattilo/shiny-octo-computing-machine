# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits 
import glob

# %%
def calibrate(file_):
    hdul = fits.open(f)
    
    data, hdr = fits.getdata(file_, header=True)   #  load in the uncalibrated frame

    cal = (data - bias) / flat


    hdu = fits.PrimaryHDU(cal, header=hdr)
    new = file_[:-5]+'_c'+file_[-5:]         #  create HDU object
    print(new)
    hdu.writeto(new, clobber=True)          #  write calibrated FITS

# %%
flat = fits.getdata('master_flat_u.fits')
bias = fits.getdata('master_bias.fits')

# %%
thar = glob.glob('final/ThAr/spec*.fits')

print(thar)


for f in thar:
    print(f)
    calibrate(f)
# Out:
# ['final/ThAr/spec0056.fits', 'final/ThAr/spec0057.fits', 'final/ThAr/spec0011.fits', 'final/ThAr/spec0010.fits', 'final/ThAr/spec0009.fits', 'final/ThAr/spec0033.fits', 'final/ThAr/spec0032.fits', 'final/ThAr/spec0058.fits']
# final/ThAr/spec0056.fits
# /Users/anne/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in divide
#
# /Users/anne/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in divide
#
# WARNING: AstropyDeprecationWarning: "clobber" was deprecated in version 2.0 and will be removed in a future version. Use argument "overwrite" instead. [astropy.utils.decorators]
# final/ThAr/spec0056_c.fits
# final/ThAr/spec0057.fits
# final/ThAr/spec0057_c.fits
# final/ThAr/spec0011.fits
# final/ThAr/spec0011_c.fits
# final/ThAr/spec0010.fits
# final/ThAr/spec0010_c.fits
# final/ThAr/spec0009.fits
# final/ThAr/spec0009_c.fits
# final/ThAr/spec0033.fits
# ...

# %%
files = glob.glob('final/*.fits')
print(files)

for f in files:
    print(f)
    calibrate(f)
# Out:
# ['final/spec0026.fits', 'final/spec0048.fits', 'final/spec0025.fits', 'final/spec0049.fits']
# final/spec0026.fits
# final/spec0026_c.fits
# /Users/anne/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in divide
#
# /Users/anne/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in divide
#
# WARNING: AstropyDeprecationWarning: "clobber" was deprecated in version 2.0 and will be removed in a future version. Use argument "overwrite" instead. [astropy.utils.decorators]
# final/spec0048.fits
# final/spec0048_c.fits
# final/spec0025.fits
# final/spec0025_c.fits
# final/spec0049.fits
# final/spec0049_c.fits
